# %%
import pyrsimg
import matplotlib.pyplot as plt
# Out:
# /Users/luo/miniconda3/envs/pyrsimg/lib/python3.9/site-packages/pyproj/__init__.py:95: UserWarning: pyproj unable to set database path.
#   _pyproj_global_context_initialize()

# %%
utm_zone = pyrsimg.get_utm_zone(lon=110)
utm_zone
# Out:
# 49
